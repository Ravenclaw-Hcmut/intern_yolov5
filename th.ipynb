# %%
# Model
import torch
# Model
model = torch.hub.load('ultralytics/yolov5', 'custom', 'yolov5/runs/train/exp2/weights/best.pt')  # or yolov5m, yolov5l, yolov5x, etc.
# model = torch.hub.load('ultralytics/yolov5', 'custom', 'path/to/best.pt')  # custom trained model
# Out:
# Using cache found in C:\Users\OS/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2022-6-24 Python-3.9.0 torch-1.11.0+cu113 CUDA:0 (NVIDIA GeForce MX130, 2048MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7020913 parameters, 0 gradients
# Adding AutoShape...

# %%
# Images
im = 'datasets/data_th/images/val/THM_250.jpg'  # or file, Path, URL, PIL, OpenCV, numpy, list

# Inference
results = model(im)

# Results
results.print()  # or .show(), .save(), .crop(), .pandas(), etc.

results.xyxy[0]  # im predictions (tensor)
results.pandas().xyxy[0]  # im predictions (pandas)
#      xmin    ymin    xmax   ymax  confidence  class    name
# 0  749.50   43.50  1148.0  704.5    0.874023      0  person
# 2  114.75  195.75  1095.0  708.0    0.624512      0  person
# 3  986.00  304.00  1028.0  420.0    0.286865     27     tie
# Out:
# image 1/1: 2560x1920 5 TH_TRUE_JUICE_MILKs, 1 TH_TRUE_RICE, 5 TH_TRUE_WATERs, 15 TH_TRUE_JUICEs
# Speed: 237.9ms pre-process, 3621.5ms inference, 109.1ms NMS per image at shape (1, 3, 640, 480)
#           xmin         ymin         xmax         ymax  confidence  class  \
# 0   937.100891  2247.126953  1062.726196  2454.268066    0.795525      2
# 1   739.725098  2176.826172   830.484741  2374.820312    0.785475      2
# 2   839.984131  2213.941162   933.849243  2432.651123    0.760657      2
# 3   641.688354  2143.634521   729.505737  2353.342041    0.600194      2
# 4   812.598145  1426.478027   927.795288  1683.157715    0.587167      3
# 5   639.374451  1813.266724   734.677307  2028.541382    0.579620      3
# 6   478.251709  1368.096191   584.394531  1610.033447    0.561388      3
# 7   413.267487   836.142883   533.508057  1141.362305    0.497956      3
# 8   579.881226  1372.173462   698.072510  1630.081665    0.490062      3
# 9   899.274536   887.760071  1046.992188  1196.076660    0.486327      3
# 10  702.799561  1395.358643   823.745483  1651.354004    0.485326      3
# 11  834.898071  1879.120361   956.911499  2108.399902    0.480007      3
# 12  950.994507  1902.437378  1072.044556  2130.025635    0.477055      3
# 13  549.899109  2103.066162   635.199768  2298.138428    0.473216      2
# 14  929.513428  1445.573486  1059.618652  1700.474854    0.472378      3
# 15  733.203125  1857.652832   835.039795  2067.479492    0.465210      3
# 16  768.905762   875.436523   910.088867  1190.602783    0.436559      3
# 17  905.016418   895.390503  1048.455078  1190.135376    0.434213      0
# 18  528.515625   847.743042   662.851929  1148.948608    0.411872      3
# 19  659.624756   875.632690   779.881470  1164.478394    0.410884      3
# 20  926.828491  1456.472900  1062.454346  1702.520996    0.393236      0
# 21  537.165466  1791.853516   632.649719  2014.640869    0.387984      3
# 22  781.721069   876.116760   912.024658  1171.696777    0.386684      0
# 23  528.437317   852.756775   654.656067  1141.139648    0.349200      0
# 24  655.073364   865.801514   773.487671  1162.609741    0.310001      0
# 25  730.086304  1849.665283   836.124146  2057.219727    0.250818      1
#
#                   name
# 0        TH_TRUE_WATER
# 1        TH_TRUE_WATER
# 2        TH_TRUE_WATER
# 3        TH_TRUE_WATER
# 4        TH_TRUE_JUICE
# 5        TH_TRUE_JUICE
# 6        TH_TRUE_JUICE
# 7        TH_TRUE_JUICE
# 8        TH_TRUE_JUICE
# 9        TH_TRUE_JUICE
# 10       TH_TRUE_JUICE
# 11       TH_TRUE_JUICE
# 12       TH_TRUE_JUICE
# 13       TH_TRUE_WATER
# 14       TH_TRUE_JUICE
# 15       TH_TRUE_JUICE
# 16       TH_TRUE_JUICE
# 17  TH_TRUE_JUICE_MILK
# 18       TH_TRUE_JUICE
# 19       TH_TRUE_JUICE
# 20  TH_TRUE_JUICE_MILK
# 21       TH_TRUE_JUICE
# 22  TH_TRUE_JUICE_MILK
# 23  TH_TRUE_JUICE_MILK
# 24  TH_TRUE_JUICE_MILK
# 25        TH_TRUE_RICE
